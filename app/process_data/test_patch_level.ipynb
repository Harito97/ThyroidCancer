# %%
from PatchLevel import PatchLevel

# %%
patch_level = PatchLevel()

# %%
# img = '/mnt/DataK/Project/ThyroidCancer/data/origin_data/B256/B5/z4840977604091_375b3cc2e326154817867ededaa2ca79.jpg'
# img = '/mnt/DataK/Project/ThyroidCancer/data/origin_data/B256/B5/z4840977650008_d71ddae75d003a6ece3d7d43ed839b7b.jpg'
# img = '/mnt/DataK/Project/ThyroidCancer/data/origin_data/B256/B5/z4904745818823_15919ec4cc2a7650351e9c528dede52f.jpg'
# img = '/mnt/DataK/Project/ThyroidCancer/data/origin_data/B256/B6/Image_142012.jpg'
# img = '/mnt/DataK/Project/ThyroidCancer/data/origin_data/B256/B6/Image_26370.jpg' # cai nay chua on -> co le nen ha conf o step 3 xuong -> hien tai model detect tot nhat van co nhuoc diem la detect nhung te bao qua xa la 1 te bao -> loang vung tap trung trong anh di
img = '/mnt/DataK/Project/ThyroidCancer/data/origin_data/B256/B6/Image_26385.jpg'
# img = '/mnt/DataK/Project/ThyroidCancer/data/origin_data/B256/B2/z4907540057168_f393de102c3ab7f2e49873cc91303c85.jpg'
# img = '/mnt/DataK/Project/ThyroidCancer/data/origin_data/B256/B2/z4907540132226_1e76f8d7eb53005233d013f93762f363.jpg'
# img = '/mnt/DataK/Project/ThyroidCancer/data/origin_data/B256/B2/z5010204306399_bec14816f4d59029d2275570cdcfc4a8.jpg'
# img = '/mnt/DataK/Project/ThyroidCancer/data/origin_data/B256/B2/z5016984356635_6091104668e76ec09f7dfe71ab3b8ea5.jpg'
# img = 'data/origin_data/B256/B2/z4907540008741_29ecba73d3d0cc14addd7cba092493d3.jpg'
img = '/mnt/DataK/Project/ThyroidCancer/data/origin_data/B256/B2/z4907540008741_29ecba73d3d0cc14addd7cba092493d3.jpg'

# %%
# result = patch_level.process(img_path=img, show_output=(True, True, True), conf=0.9, threshold=25)  # for B2
# result = patch_level.process(img_path=img, show_output=(True, True, True), conf=0.9, threshold=10)  # for B5
result = patch_level.process(img_path=img, show_output=(True, True, True), conf=0.9, threshold=10)  # for B6
# Out:
# 0: 640x800 286 cells, 1632.9ms
# Speed: 11.2ms preprocess, 1632.9ms inference, 4.6ms postprocess per image at shape (1, 3, 640, 800)
# 0: 800x800 10 cells, 2724.2ms
# Speed: 8.3ms preprocess, 2724.2ms inference, 1.8ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 8 cells, 2397.0ms
# Speed: 9.0ms preprocess, 2397.0ms inference, 2.4ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 14 cells, 2759.4ms
# Speed: 10.6ms preprocess, 2759.4ms inference, 1.3ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 13 cells, 3275.5ms
# Speed: 9.2ms preprocess, 3275.5ms inference, 1.2ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 7 cells, 2661.9ms
# Speed: 10.7ms preprocess, 2661.9ms inference, 4.2ms postprocess per image at shape (1, 3, 800, 800)

# %%
result = patch_level.process(img_path=img, show_output=(True, True, True), conf=0.9, threshold=10)  # for B2
# Out:
# 0: 608x800 52 cells, 4403.7ms
# Speed: 48.2ms preprocess, 4403.7ms inference, 10.6ms postprocess per image at shape (1, 3, 608, 800)
# 0: 800x800 18 cells, 5473.5ms
# Speed: 10.5ms preprocess, 5473.5ms inference, 2.9ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 17 cells, 3836.3ms
# Speed: 19.4ms preprocess, 3836.3ms inference, 1.8ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 34 cells, 3316.5ms
# Speed: 10.3ms preprocess, 3316.5ms inference, 1.5ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 17 cells, 3844.5ms
# Speed: 12.7ms preprocess, 3844.5ms inference, 1.5ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 24 cells, 4710.8ms
# Speed: 16.3ms preprocess, 4710.8ms inference, 1.5ms postprocess per image at shape (1, 3, 800, 800)

# %%
# PatchLevel.save_result(result, label='B5', img_origin_id='z4904745818823_15919ec4cc2a7650351e9c528dede52f.jpg')

# %%
# result = patch_level.step1(img, show_output=True)

# %%
# result = patch_level.step2(result, show_output=True)

# %%
# result = patch_level.step3(result, show_output=True)
